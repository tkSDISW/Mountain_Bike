# %% [markdown]
# # Interactive Chat

# %%
from se_agent.core.agent import AgentCore

agent = AgentCore()
agent.create_package("BikeProject")
agent.use_package("BikeProject")


result = agent.run("llm_chat", input_data={
    "prompt": "Summarize the purpose of a braking system in one sentence.",
    "context": "You are a systems engineering expert."
})

print(result["response"])
# Start interactive chat with file attach + artifact capture
# Call chat as a tool
agent.run("interactive_chat", input_data={
    "context": "You are a systems engineering assistant."
}, agent=agent)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# 📌 Artifact created: id='e1b177e2' type='conversation' in package 'BikeProject'
# The purpose of a braking system is to safely reduce the speed of a vehicle or bring it to a complete stop by converting kinetic energy into heat through friction or other means.
# Output()
# Textarea(value='', layout=Layout(border_bottom='2px solid #4A90E2', border_left='2px solid #4A90E2', border_ri…
# HBox(children=(Button(button_style='primary', description='Execute', style=ButtonStyle()), Button(button_style…
# Dropdown(description='Load file:', layout=Layout(width='auto'), options=('', 'engine_pipeline.json', 'landingg…
# 💬 Interactive chat started. Use `run:tool {json}` to call tools. Exit button to close.
# {'message': "👋 Interactive chat closed\n📌 Alias 'BOM' assigned to artifact id='0dcf8b06' type='hierarchy' in package 'BikeProject'",
#  'artifact_message': "📌 Alias 'BOM' assigned to artifact id='0dcf8b06' type='hierarchy' in package 'BikeProject'"}

# %%
pkg = agent.artifacts.get_active_package()
print([ (a.type, a.content) for a in pkg.artifacts.values() if a.type == "conversation"])

result = agent.run("notebook_export", input_data={"filename": "replay.ipynb"}, agent=agent)
print(result)
# Out:
# [('conversation', {'prompt': 'Summarize the purpose of a braking system in one sentence.', 'response': 'The purpose of a braking system is to safely reduce the speed of a vehicle or bring it to a complete stop by converting kinetic energy into heat through friction or other means.'}), ('conversation', {'prompt': 'load leveled csv drone.csv', 'response': 'To load a leveled CSV file, we first need to read the file using the `read_leveled_csv` tool.\n\n```json\n{"actions": [\n    {"tool": "read_leveled_csv", "input": {"filename": "drone.csv"}}\n]}\n```'}), ('conversation', {'prompt': 'refer to as BOM', 'response': 'To assign a human-friendly alias to the most recently loaded hierarchy artifact, we\'ll use the `alias_artifact` tool.\n\n```json\n{"actions": [\n    {"tool": "alias_artifact", "input": {"type": "hierarchy", "alias": "BOM"}}\n]}\n```'}), ('conversation', {'prompt': 'shoe BOM', 'response': 'It seems like there was a typo in your request for "shoe BOM," which might be meant as "show BOM." Let\'s display the artifact using the alias "BOM."\n\n```json\n{"actions": [\n    {"tool": "show_artifact", "input": {"alias": "BOM"}}\n]}\n```'}), ('conversation', {'prompt': 'generate engineering report from BOM', 'response': 'To generate an engineering report from the artifact aliased as "BOM," we\'ll use the `format_json_report` tool.\n\n```json\n{"actions": [\n    {"tool": "format_json_report", "input": {"alias": "BOM"}}\n]}\n```'})]
# {'message': "📓 Notebook exported to replay.ipynb\n📌 Alias 'BOM' assigned to artifact id='0dcf8b06' type='hierarchy' in package 'BikeProject'", 'filename': 'replay.ipynb', 'artifact_message': "📌 Alias 'BOM' assigned to artifact id='0dcf8b06' type='hierarchy' in package 'BikeProject'"}
