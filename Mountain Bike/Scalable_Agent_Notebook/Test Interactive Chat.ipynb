# %% [markdown]
# # Interactive Chat

# %%
from se_agent.core.agent import AgentCore

agent = AgentCore()
agent.create_package("BikeProject")
agent.use_package("BikeProject")
resources = {
    "Mountain_Bike": "Mountain_Bike/Mountain Bike",
    "Bike BrakeSystem Library": {"path" : "/home/simcenter/studio/Bike_BrakeSystem_Library/Bike BrakeSystem Library"}
}
agent.run(
    "create_artifact",
    input_data={
        "content": "../Mountain Bike.aird",
        "name": "Bike_Path",
        "type": "capella_model_path",
        # "metadata": {"note": "primary Capella model path"}  # optional
    },
    package_name="BikeProject",  # omit if active
)

resources = {
    "Mountain_Bike": "Mountain_Bike/Mountain Bike",
    "Bike BrakeSystem Library": {
        "path": "/home/simcenter/studio/Bike_BrakeSystem_Library/Bike BrakeSystem Library"
    }
}

agent.run(
    "create_artifact",
    input_data={
        "content": resources,
        "name": "Bike_Resources",
        "type": "capella_resources",
    },
    package_name="BikeProject",
)
agent.run('create_artifact', input_data={'type': 'prompt', 'content': 'Locate and report on all Logical Components', 'name': 'prompt'})

# Start interactive chat with file attach + artifact capture
# Call chat as a tool
agent.run("interactive_chat", input_data={
    "context": "You are a systems engineering assistant."
}, agent=agent)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ✅ Artifact created: name='Bike_Path' id='1dd8522d' type='capella_model_path' in package 'BikeProject'
# ✅ Artifact created: name='Bike_Resources' id='d12087a2' type='capella_resources' in package 'BikeProject'
# ✅ Artifact created: name='prompt' id='126baebd' type='prompt' in package 'BikeProject'
# Output()
# Textarea(value='', layout=Layout(border_bottom='2px solid #4A90E2', border_left='2px solid #4A90E2', border_ri…
# HBox(children=(Button(button_style='primary', description='Execute', style=ButtonStyle()), Button(button_style…
# Dropdown(description='Load file:', layout=Layout(width='auto'), options=('', 'engine_pipeline.json', 'landingg…
# 💬 Interactive chat started. Use `run:tool {json}` to call tools. Exit button to close.
# {'message': "👋 Interactive chat closed\n✅ name 'CS_yaml' assigned to artifact id='d6c1ceaf' type='yaml_content' in package 'BikeProject'",
#  'artifact_message': "✅ name 'CS_yaml' assigned to artifact id='d6c1ceaf' type='yaml_content' in package 'BikeProject'"}

# %%
pkg = agent.artifacts.get_active_package()
print([ (a.type, a.content) for a in pkg.artifacts.values() if a.type == "conversation"])

result = agent.run("notebook_export", input_data={"filename": "replay.ipynb"}, agent=agent)
print(result)
# Out:
# [('conversation', {'prompt': 'query the capella model with prompt "Logical Architecture [LAB] Mountain Bike Messy" return the top 1 response use Bike_Path and Bike_Resources', 'response': 'To query the Capella model, I\'ll use the prompt "Logical Architecture [LAB] Mountain Bike Messy" and return the top result using the specified model path and resources. Let\'s proceed with this action.\n\n{"actions":[{"tool":"query_capella_model","input":{"query":"Logical Architecture [LAB] Mountain Bike Messy","top_n":1,"model_path_name":"Bike_Path","resources_name":"Bike_Resources"}}]}'}), ('conversation', {'prompt': 'name capella_selection CS', 'response': '{"actions":[{"tool":"name_artifact","input":{"type":"capella_selection","name":"CS"}}]}'}), ('conversation', {'prompt': 'Create capella yaml from Bike_Path Bike_Resources and CS', 'response': '{"actions":[{"tool":"generate_capella_yaml","input":{"selection_name":"CS","model_path_name":"Bike_Path","resources_name":"Bike_Resources"}}]}'}), ('conversation', {'prompt': 'format yaml report from CS_yaml and artifact named prompt', 'response': '{"actions":[{"tool":"format_yaml_report","input":{"yaml_content_name":"CS_yaml","prompt_name":"prompt"}}]}'})]
# {'message': "📓 Notebook exported to replay.ipynb\n✅ name 'CS_yaml' assigned to artifact id='d6c1ceaf' type='yaml_content' in package 'BikeProject'", 'filename': 'replay.ipynb', 'artifact_message': "✅ name 'CS_yaml' assigned to artifact id='d6c1ceaf' type='yaml_content' in package 'BikeProject'"}
