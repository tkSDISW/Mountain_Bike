# %% [markdown]
# # Agent Replay Notebook
# Generated from agent history.

# %% [markdown]
# ### Step 1: Run `llm_chat`
# Prompt: `Summarize the purpose of a braking system in one sentence.`

# %%
agent.run('llm_chat', input_data={'prompt': 'Summarize the purpose of a braking system in one sentence.'})

# %% [markdown]
# ### Step 2: Run `llm_chat`
# Prompt: `list tools`

# %%
agent.run('llm_chat', input_data={'prompt': 'list tools'})

# %% [markdown]
# ### Step 3: Run `llm_chat`
# Prompt: `Please list the tools again.`

# %%
agent.run('llm_chat', input_data={'prompt': 'Please list the tools again.'})

# %% [markdown]
# ### Step 4: Run `llm_chat`
# Prompt: `load a leveled csv drone.csv`

# %%
agent.run('llm_chat', input_data={'prompt': 'load a leveled csv drone.csv'})

# %% [markdown]
# ### Step 5: Run `read_leveled_csv`
# Input: `{'filename': 'drone.csv'}`

# %%
_ = agent.run('read_leveled_csv', input_data={'filename': 'drone.csv'})
