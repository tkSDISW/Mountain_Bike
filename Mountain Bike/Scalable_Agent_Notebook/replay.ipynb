# %% [markdown]
# # Agent Replay Notebook
# Generated from agent history.

# %% [markdown]
# ### Step 1: Run `save_artifact`
# Input: `{'content': '../Mountain Bike.aird', 'alias': 'Bike_Path', 'type': 'capella_model_path'}`

# %%
_ = agent.run('save_artifact', input_data={'content': '../Mountain Bike.aird', 'alias': 'Bike_Path', 'type': 'capella_model_path'})

# %% [markdown]
# ### Step 2: Run `save_artifact`
# Input: `{'content': {'Mountain_Bike': 'Mountain_Bike/Mountain Bike', 'Bike BrakeSystem Library': {'path': '/home/simcenter/studio/Bike_BrakeSystem_Library/Bike BrakeSystem Library'}}, 'alias': 'Bike_Resources', 'type': 'capella_resources'}`

# %%
_ = agent.run('save_artifact', input_data={'content': {'Mountain_Bike': 'Mountain_Bike/Mountain Bike', 'Bike BrakeSystem Library': {'path': '/home/simcenter/studio/Bike_BrakeSystem_Library/Bike BrakeSystem Library'}}, 'alias': 'Bike_Resources', 'type': 'capella_resources'})

# %% [markdown]
# ### Step 3: Run `save_artifact`
# Input: `{'type': 'prompt', 'content': 'Locate and report on all Logical Components', 'alias': 'prompt'}`

# %%
_ = agent.run('save_artifact', input_data={'type': 'prompt', 'content': 'Locate and report on all Logical Components', 'alias': 'prompt'})

# %% [markdown]
# ### Step 4: Run `llm_chat`
# Prompt: `query the capella model with prompt "[LAB] Mountain Bike Messy" return the top 1 response use Bike_Path and Bike_Resources`

# %%
agent.run('llm_chat', input_data={'prompt': 'query the capella model with prompt "[LAB] Mountain Bike Messy" return the top 1 response use Bike_Path and Bike_Resources'})

# %% [markdown]
# ### Step 5: Run `query_capella_embeddings`
# Input: `{'query': '[LAB] Mountain Bike Messy', 'top_n': 1, 'model_path_alias': 'Bike_Path', 'resources_alias': 'Bike_Resources'}`

# %%
_ = agent.run('query_capella_embeddings', input_data={'query': '[LAB] Mountain Bike Messy', 'top_n': 1, 'model_path_alias': 'Bike_Path', 'resources_alias': 'Bike_Resources'})

# %% [markdown]
# ### Step 6: Run `llm_chat`
# Prompt: `alias capella_selection as CS`

# %%
agent.run('llm_chat', input_data={'prompt': 'alias capella_selection as CS'})

# %% [markdown]
# ### Step 7: Run `alias_artifact`
# Input: `{'type': 'capella_selection', 'alias': 'CS'}`

# %%
_ = agent.run('alias_artifact', input_data={'type': 'capella_selection', 'alias': 'CS'})

# %% [markdown]
# ### Step 8: Run `llm_chat`
# Prompt: `export capella yaml from CS, Bike_Path, Bike_Resources`

# %%
agent.run('llm_chat', input_data={'prompt': 'export capella yaml from CS, Bike_Path, Bike_Resources'})

# %% [markdown]
# ### Step 9: Run `export_capella_yaml`
# Input: `{'selection_alias': 'CS', 'model_path_alias': 'Bike_Path', 'resources_alias': 'Bike_Resources'}`

# %%
_ = agent.run('export_capella_yaml', input_data={'selection_alias': 'CS', 'model_path_alias': 'Bike_Path', 'resources_alias': 'Bike_Resources'})

# %% [markdown]
# ### Step 10: Run `llm_chat`
# Prompt: `format yaml report from CS_yaml and promt : "prompt"`

# %%
agent.run('llm_chat', input_data={'prompt': 'format yaml report from CS_yaml and promt : "prompt"'})

# %% [markdown]
# ### Step 11: Run `format_yaml_report`
# Input: `{'yaml_content_alias': 'CS_yaml', 'prompt_alias': 'prompt'}`

# %%
_ = agent.run('format_yaml_report', input_data={'yaml_content_alias': 'CS_yaml', 'prompt_alias': 'prompt'})
