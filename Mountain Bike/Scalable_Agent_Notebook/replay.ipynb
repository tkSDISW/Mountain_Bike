# %% [markdown]
# # Agent Replay Notebook
# Generated from agent history.

# %% [markdown]
# ### Step 1: Run `create_capella_model_artifact`
# Input: `{'path_to_model': '/home/simcenter/studio/SE_Agent/SE_Agent/SE_Agent.aird', 'resources': {'SE_Agent': '/home/simcenter/studio/SE_Agent/SE_Agent/'}}`

# %%
_ = agent.run('create_capella_model_artifact', input_data={'path_to_model': '/home/simcenter/studio/SE_Agent/SE_Agent/SE_Agent.aird', 'resources': {'SE_Agent': '/home/simcenter/studio/SE_Agent/SE_Agent/'}})

# %% [markdown]
# ### Step 2: Run `load_prompt_path`
# Input: `{'prompt_dir_path': '/home/simcenter/studio/Mountain_Bike/Mountain Bike/Scalable_Agent_Notebook/My_Prompts/'}`

# %%
_ = agent.run('load_prompt_path', input_data={'prompt_dir_path': '/home/simcenter/studio/Mountain_Bike/Mountain Bike/Scalable_Agent_Notebook/My_Prompts/'})

# %% [markdown]
# ### Step 3: Run `list_workspace`

# %%
_ = agent.run('list_workspace', input_data={})
