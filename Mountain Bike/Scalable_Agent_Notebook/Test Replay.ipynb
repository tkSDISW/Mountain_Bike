# %%
from rag_manager.core.agent import AgentCore

agent = AgentCore()
# run some tools
agent.run("wordcount", input_data="Landing gear is essential")
agent.run("summarizer", input_data="Landing gear is essential")

# export notebook via tool
result = agent.run("notebook_export", input_data={"filename": "replay.ipynb"}, agent=agent)
print(result)
# Out:
# {'message': '📓 Notebook exported to replay.ipynb', 'filename': 'replay.ipynb'}
