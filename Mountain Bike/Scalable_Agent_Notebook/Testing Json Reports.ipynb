# %%
from rag_manager.core.agent import AgentCore

agent = AgentCore()
agent.create_package("BikeProject")
agent.use_package("BikeProject")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from rag_manager.core.agent import AgentCore
#       3 agent = AgentCore()
#       4 agent.create_package("BikeProject")
#
# ModuleNotFoundError: No module named 'rag_manager'

# %% [markdown]
# # Agent Replay Notebook
# Generated from agent history.

# %% [markdown]
# ### Step 1: Run `llm_chat`
# Prompt: `Summarize the purpose of a braking system in one sentence.`

# %%
agent.run('llm_chat', input_data={'prompt': 'Summarize the purpose of a braking system in one sentence.'})

# %% [markdown]
# ### Step 2: Run `llm_chat`
# Prompt: `Read leveled csv drone.csv`

# %%
agent.run('llm_chat', input_data={'prompt': 'Read leveled csv drone.csv'})

# %% [markdown]
# ### Step 3: Run `read_leveled_csv`
# Input: `{'filename': 'drone.csv'}`

# %%
agent.run('read_leveled_csv', input_data={'filename': 'drone.csv'})

# %% [markdown]
# ### Step 4: Run `llm_chat`
# Prompt: `alias the hierarchy`

# %%
agent.run('llm_chat', input_data={'prompt': 'alias the hierarchy'})

# %% [markdown]
# ### Step 5: Run `alias_artifact`
# Input: `{'type': 'hierarchy', 'alias': 'drone_hierarchy'}`

# %%
agent.run('alias_artifact', input_data={'type': 'hierarchy', 'alias': 'drone_hierarchy'})

# %% [markdown]
# ### Step 6: Run `llm_chat`
# Prompt: `format the drone_hierarchy`

# %%
agent.run('llm_chat', input_data={'prompt': 'format the drone_hierarchy'})

# %% [markdown]
# ### Step 7: Run `format_json_report`
# Input: `{'artifact': 'drone_hierarchy'}`

# %%
agent.run('format_json_report', input_data={'artifact': 'drone_hierarchy'})
