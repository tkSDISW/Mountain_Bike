# %%
from Open_AI_MBSE_Agent import MBSEAgent
from capella_tools.model_configurator import get_api_key


mbse = MBSEAgent()
mbse._list_tools_tool()
# Out:
# ...
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# ✅ Agent initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# {'message': 'Here are the tools I can use:',
#  'tools': [{'name': 'apply_description',
#    'description': 'Update the textual description of an existing model element. Use this tool only when the user asks to *modify* or *add a description* for a component, subsystem, or object that already exists. Input JSON format: {"uuid":"<target_uuid>", "description":"<text>"}. Example: {"uuid":"1234", "description":"Pressurizes fuel for the engine"}.'},
#   {'name': 'add_logical_components',
# ...

# %%
mbse._write_csv_tool({
    "filename": "test_simple.csv",
    "data": [
        {"ReqID": "R1", "Text": "System shall brake"},
        {"ReqID": "R2", "Text": "System shall steer"}
    ]
})
# Out:
# {'message': '💾 Saved simple CSV to test_simple.csv',
#  'rows': 2,
#  'columns': ['ReqID', 'Text']}

# %%
import pandas as pd
print(pd.read_csv("test_simple.csv"))
# Out:
#   ReqID                Text
# 0    R1  System shall brake
# 1    R2  System shall steer

# %% [markdown]
# Simple CSV Read

# %%
print(mbse.run_agent('Read CSV {"filename":"test_simple.csv"}'))
# Out:
# 🔎 Debug mode ON — streaming steps...
# Step: {'agent': {'messages': [AIMessage(content='How can I assist you today with your model-based systems engineering tasks?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 1098, 'total_tokens': 1113, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CImS6WY4jgbupkaizpnhi07W6u5DV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2b1a13ed-2139-4852-9eb1-4c80e0a2535d-0', usage_metadata={'input_tokens': 1098, 'output_tokens': 15, 'total_tokens': 1113, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ...

# %%
print(mbse.run_agent(
    'Write CSV {"filename":"test_simple.csv", "data":[{"ReqID":"R1","Text":"System shall brake"}, {"ReqID":"R2","Text":"System shall steer"}]}'
))
# Out:
# 🔎 Debug mode ON — streaming steps...
# Step: {'agent': {'messages': [AIMessage(content='How can I assist you today with your model-based systems engineering tasks?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 1098, 'total_tokens': 1113, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CImSDfEPXR3ToYLb2Vo7P5YhOvHXZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--c3a17d09-e48e-48b3-acf8-550834efafea-0', usage_metadata={'input_tokens': 1098, 'output_tokens': 15, 'total_tokens': 1113, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# ...
