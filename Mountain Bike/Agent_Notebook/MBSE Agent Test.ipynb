# %%
from Open_AI_MBSE_Agent import MBSEAgent
from capella_tools.model_configurator import get_api_key


mbse = MBSEAgent()

# Ask the agent to start your widget-based chat
# Ask the agent to start your widget-based chat
print(mbse.run_agent('Interactive chat'))
# Out:
# ...
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# ✅ Agent initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Here are the tools I can use:
#
# 1. **apply_description**: Update the textual description of an existing model element. This is used when modifying or adding a description for already existing components, subsystems, or objects.
#
# 2. **add_logical_components**: Create new Logical Components in the Capella model. This is used when adding, creating, or inserting subsystems, blocks, or components.
#
# 3. **bpmn_to_capella**: Convert a BPMN process model into a Capella function chain. Use this to translate workflows, processes, or BPMN files into Capella.
#
# 4. **capella_to_bpmn**: Convert Capella YAML into a BPMN diagram. This is used to derive process/flow diagrams from Capella.
#
# ...

# %%
print(mbse.run_agent('what tools do you have?'))
# Out:
# Here are the tools I can use:
#
# 1. **apply_description**: Update the textual description of an existing model element. Used when modifying or adding a description to a component, subsystem, or object that already exists.
#
# 2. **add_logical_components**: Create new Logical Components in the Capella model. Use this for adding, creating, or inserting subsystems, blocks, or components.
#
# 3. **bpmn_to_capella**: Convert a BPMN process model into a Capella function chain. Used for translating workflows, processes, or BPMN files into Capella.
#
# 4. **capella_to_bpmn**: Convert Capella YAML into a BPMN diagram. This is used for creating process/flow diagrams derived from Capella.
#
# 5. **analyze_graph**: Generate a PyVis relationship graph to visualize model relationships such as dependencies or functional chains.
#
# 6. **save_to_word**: Save the most recent assistant response as a Word document.
#
# 7. **save_to_csv**: Save the most recent assistant response as a CSV file.
#
# ...

# %%
print(mbse.run_agent('Give me an example of of you capabilities'))
# Out:
# How can I assist you with Model-Based Systems Engineering today?

# %%
print(mbse.run_agent('Yes'))
# Out:
# How can I assist you with Model-Based Systems Engineering today? If you have a specific request or need help with model elements, feel free to ask!
