# %%
import capellambse.decl

from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "Mountain_Bike": "Mountain_Bike/Mountain Bike",
    "Bike BrakeSystem Library": {"path" : "/home/simcenter/studio/Bike_BrakeSystem_Library/Bike BrakeSystem Library"}
}
path_to_model = "../Mountain Bike.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)

from capella_tools import Pub4C
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../Mountain Bike.traceability")
# Out:
# Warning: File '../Mountain Bike.traceability' does not exist.

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[LAB] Mountain Bike All (Messy)", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [LAB] Mountain Bike All (Messy), Similarity: 0.79, Type: Diagram, Phase: Logical Architecture LA, Source: , Target:

# %%
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    if object["type"] == "Diagram" :
        yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  
    else:
        yaml_handler.generate_yaml( model.search(object["type"]).by_uuid(object["uuid"]))


yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %%
# In your notebook (run once per kernel)
import sys, os
sys.path.append(os.getcwd())  # if the notebook’s CWD is the repo root containing /agent
# or, if the package is one level up:
# sys.path.append(os.path.abspath(".."))

from agent import MBSEAgent
yaml_content = yaml_handler.get_yaml_content()


mbse = MBSEAgent(debug=True)

#mbse = MBSEAgent()


# CSV tests
print(mbse.run_agent('Load YAML {"filename":"capella_model.yaml"}'))
print(mbse.run_agent('Use direct_yaml_query {"prompt":"List all Logical Components"}'))
# Out:
# ✅ Agent initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# 🔎 Debug mode ON — streaming steps...
# Step: {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_tNtuHEK7NqPGSwrh34Ikzyaz', 'function': {'arguments': '{"filename":"capella_model.yaml"}', 'name': 'load_yaml_file'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1027, 'total_tokens': 1045, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CJnbiKrGvobc2uQgaEiD2J8yr6jII', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--7c18424b-532b-4abc-bebd-55f17209a616-0', tool_calls=[{'name': 'load_yaml_file', 'args': {'filename': 'capella_model.yaml'}, 'id': 'call_tNtuHEK7NqPGSwrh34Ikzyaz', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1027, 'output_tokens': 18, 'total_tokens': 1045, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# Step: {'tools': {'messages': [ToolMessage(content='{"ok": true, "message": "Loaded YAML from capella_model.yaml", "bytes": 108353}', name='load_yaml_file', id='70f50c0c-4a6e-4e30-b0ab-e90dc2649432', tool_call_id='call_tNtuHEK7NqPGSwrh34Ikzyaz')]}}
# Step: {'agent': {'messages': [AIMessage(content='The YAML file "capella_model.yaml" has been successfully loaded into memory. How can I assist you further with this model?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 1078, 'total_tokens': 1105, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CJnbk4f1jVxUrKRN8Mpqelf70bJyG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--aa31b6bd-67b9-4537-a91a-02ba8cf4daca-0', usage_metadata={'input_tokens': 1078, 'output_tokens': 27, 'total_tokens': 1105, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# The YAML file "capella_model.yaml" is already loaded in memory. You can proceed with any queries or operations on this model. How can I assist you further?
# 🔎 Debug mode ON — streaming steps...
# Step: {'agent': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_xnIroqzK0j8Udt4vjv8Cag5z', 'function': {'arguments': '{"prompt":"List all Logical Components"}', 'name': 'direct_yaml_query'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1221, 'total_tokens': 1239, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CJnbnnioSIxOZ3hwfjx1kExFntKsr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--886bffe5-9f19-44d8-917e-2b09cdc3c90d-0', tool_calls=[{'name': 'direct_yaml_query', 'args': {'prompt': 'List all Logical Components'}, 'id': 'call_xnIroqzK0j8Udt4vjv8Cag5z', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1221, 'output_tokens': 18, 'total_tokens': 1239, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# Step: {'tools': {'messages': [ToolMessage(content='Listing logical components is not yet implemented in this stub.', name='direct_yaml_query', id='596b22e3-9811-4146-9659-bbdc19759c69', tool_call_id='call_xnIroqzK0j8Udt4vjv8Cag5z')]}}
# Step: {'agent': {'messages': [AIMessage(content="It seems that the functionality to list all Logical Components from the YAML model is not yet implemented. If there's anything else you'd like to do with the model, please let me know!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 1259, 'total_tokens': 1296, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CJnboawULUPz03ndq9W9f8FbOwNup', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--09472b5e-33f3-4142-97ca-8cf61d3c06ee-0', usage_metadata={'input_tokens': 1259, 'output_tokens': 37, 'total_tokens': 1296, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# It seems that the functionality to list all Logical Components from the YAML model is not yet implemented. If there's anything else you'd like to do with the model, please let me know!

# %%
mbse.interactive_chat()
# Out:
# Starting interactive chat (Agent mode)...
# Output()
# Textarea(value='', layout=Layout(border_bottom='2px solid #4A90E2', border_left='2px solid #4A90E2', border_ri…
# HBox(children=(Button(button_style='primary', description='Execute', style=ButtonStyle()), Button(button_style…
# Dropdown(description='Load file:', layout=Layout(width='auto'), options=('', 'test_simple.csv', 'fred.csv', 'o…
# Waiting for chat interactions...
